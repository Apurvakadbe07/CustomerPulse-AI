# %% [markdown]
# # SQL Business Analysis
#
# ## Objective
#
# The objective of this analysis is to extract business insights from the Customer 360 dataset using SQL.
#
# This analysis focuses on:
# - Customer behaviour analysis
# - Revenue analysis
# - Purchase analysis
# - Customer experience analysis
# - Business KPI generation

# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import text

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql://postgres:postgres123@localhost:5432/customerpulse_ai"
)

connection = engine.connect()

print("Connection Successful")
# Out:
# Connection Successful

# %%
import pandas as pd

file_path = r"D:\customer pulse AI project\1 data\03_analysis\customer_360_clean.csv"

df = pd.read_csv(file_path)

schema = pd.DataFrame({
    "Column": df.columns,
    "Data Type": df.dtypes.astype(str)
})

print("Shape:", df.shape)
display(schema)
# Out:
# Shape: (96096, 38)
#                                                     Column Data Type
# customer_unique_id                      customer_unique_id       str
# customer_city                                customer_city       str
# customer_state                              customer_state       str
# total_orders                                  total_orders     int64
# delivered_orders                          delivered_orders     int64
# cancelled_orders                          cancelled_orders     int64
# first_purchase_date                    first_purchase_date       str
# last_purchase_date                      last_purchase_date       str
# total_spent                                    total_spent   float64
# average_order_value                    average_order_value   float64
# maximum_order_value                    maximum_order_value   float64
# minimum_order_value                    minimum_order_value   float64
# ...
